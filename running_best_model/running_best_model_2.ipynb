# %%
# preparing package, object, and library
import pandas as pd
import numpy as np

# %%
from sklearn.feature_selection import chi2
from sklearn.model_selection import train_test_split
# 1. normalization 
from sklearn.preprocessing import MinMaxScaler

# %%
X_train1, X_test1, y_train1,y_test1 = np.load('X_train1.npy'),np.load('X_test1.npy'),np.load('y_train1.npy'),np.load('y_test1.npy')
X_train2, X_test2, y_train2,y_test2 = np.load('X_train2.npy'),np.load('X_test2.npy'),np.load('y_train2.npy'),np.load('y_test2.npy')
X_train3, X_test3, y_train3,y_test3 = np.load('X_train3.npy'),np.load('X_test3.npy'),np.load('y_train3.npy'),np.load('y_test3.npy')
X_train4, X_test4, y_train4,y_test4 = np.load('X_train4.npy'),np.load('X_test4.npy'),np.load('y_train4.npy'),np.load('y_test4.npy')

scaler = MinMaxScaler()
scaler.fit(X_train1)
X_normal1 = scaler.transform(X_train1)
scaler.fit(X_train2)
X_normal2 = scaler.transform(X_train2)
scaler.fit(X_train3)
X_normal3 = scaler.transform(X_train3)
scaler.fit(X_train4)
X_normal4 = scaler.transform(X_train4)

# %%
def get_bad_features(pValue,thr):
    list_bad_feature=[]
    for i in range(len(pValue)):
        if pValue[i] < thr:
            list_bad_feature.append(i)
    return list_bad_feature

# %run ./best_featureRNA.ipynb 
# %run ./Data_Conversion_1.ipynb
# %run ./ML_Module_v1.ipynb
# %run ./Performances_Module_2.ipynb
# %run ./Data_Visualization_1.ipynb

# %%
# total features are PseKNC and PSTNPss
# 66(64 + 2lambda) + 39
myTriIndex = {
    'AAA': 0, 'AAC': 1, 'AAG': 2, 'AAU': 3,
    'ACA': 4, 'ACC': 5, 'ACG': 6, 'ACU': 7,
    'AGA': 8, 'AGC': 9, 'AGG': 10, 'AGU': 11,
    'AUA': 12, 'AUC': 13, 'AUG': 14, 'AUU': 15,
    'CAA': 16, 'CAC': 17, 'CAG': 18, 'CAU': 19,
    'CCA': 20, 'CCC': 21, 'CCG': 22, 'CCU': 23,
    'CGA': 24, 'CGC': 25, 'CGG': 26, 'CGU': 27,
    'CUA': 28, 'CUC': 29, 'CUG': 30, 'CUU': 31,
    'GAA': 32, 'GAC': 33, 'GAG': 34, 'GAU': 35,
    'GCA': 36, 'GCC': 37, 'GCG': 38, 'GCU': 39,
    'GGA': 40, 'GGC': 41, 'GGG': 42, 'GGU': 43,
    'GUA': 44, 'GUC': 45, 'GUG': 46, 'GUU': 47,
    'UAA': 48, 'UAC': 49, 'UAG': 50, 'UAU': 51,
    'UCA': 52, 'UCC': 53, 'UCG': 54, 'UCU': 55,
    'UGA': 56, 'UGC': 57, 'UGG': 58, 'UGU': 59,
    'UUA': 60, 'UUC': 61, 'UUG': 62, 'UUU': 63
}
feature_idx =[]
for keys in myTriIndex:
    feature_idx.append('PseKNC_'+keys)

feature_idx.append('PseKNC_lambda1')
feature_idx.append('PseKNC_lambda2')

for idx in range(39):
    feature_idx.append('PSTNPss_'+str(idx))
X_normal3.shape
feature_idx
# Out:
# ['PseKNC_AAA',
#  'PseKNC_AAC',
#  'PseKNC_AAG',
#  'PseKNC_AAU',
#  'PseKNC_ACA',
#  'PseKNC_ACC',
#  'PseKNC_ACG',
#  'PseKNC_ACU',
#  'PseKNC_AGA',
#  'PseKNC_AGC',
#  'PseKNC_AGG',
#  'PseKNC_AGU',
#  'PseKNC_AUA',
#  'PseKNC_AUC',
#  'PseKNC_AUG',
#  'PseKNC_AUU',
#  'PseKNC_CAA',
#  'PseKNC_CAC',
#  'PseKNC_CAG',
#  'PseKNC_CAU',
#  'PseKNC_CCA',
#  'PseKNC_CCC',
#  'PseKNC_CCG',
#  'PseKNC_CCU',
#  'PseKNC_CGA',
#  'PseKNC_CGC',
#  'PseKNC_CGG',
#  'PseKNC_CGU',
#  'PseKNC_CUA',
#  'PseKNC_CUC',
#  'PseKNC_CUG',
#  'PseKNC_CUU',
#  'PseKNC_GAA',
#  'PseKNC_GAC',
#  'PseKNC_GAG',
#  'PseKNC_GAU',
#  'PseKNC_GCA',
#  'PseKNC_GCC',
#  'PseKNC_GCG',
#  'PseKNC_GCU',
#  'PseKNC_GGA',
#  'PseKNC_GGC',
#  'PseKNC_GGG',
#  'PseKNC_GGU',
#  'PseKNC_GUA',
#  'PseKNC_GUC',
#  'PseKNC_GUG',
#  'PseKNC_GUU',
#  'PseKNC_UAA',
#  'PseKNC_UAC',
#  'PseKNC_UAG',
#  'PseKNC_UAU',
#  'PseKNC_UCA',
#  'PseKNC_UCC',
#  'PseKNC_UCG',
#  'PseKNC_UCU',
#  'PseKNC_UGA',
#  'PseKNC_UGC',
#  'PseKNC_UGG',
#  'PseKNC_UGU',
#  'PseKNC_UUA',
#  'PseKNC_UUC',
#  'PseKNC_UUG',
#  'PseKNC_UUU',
#  'PseKNC_lambda1',
#  'PseKNC_lambda2',
#  'PSTNPss_0',
#  'PSTNPss_1',
#  'PSTNPss_2',
#  'PSTNPss_3',
#  'PSTNPss_4',
#  'PSTNPss_5',
#  'PSTNPss_6',
#  'PSTNPss_7',
#  'PSTNPss_8',
#  'PSTNPss_9',
#  'PSTNPss_10',
#  'PSTNPss_11',
#  'PSTNPss_12',
#  'PSTNPss_13',
#  'PSTNPss_14',
#  'PSTNPss_15',
#  'PSTNPss_16',
#  'PSTNPss_17',
#  'PSTNPss_18',
#  'PSTNPss_19',
#  'PSTNPss_20',
#  'PSTNPss_21',
#  'PSTNPss_22',
#  'PSTNPss_23',
#  'PSTNPss_24',
#  'PSTNPss_25',
#  'PSTNPss_26',
#  'PSTNPss_27',
#  'PSTNPss_28',
#  'PSTNPss_29',
#  'PSTNPss_30',
#  'PSTNPss_31',
#  'PSTNPss_32',
#  'PSTNPss_33',
#  'PSTNPss_34',
#  'PSTNPss_35',
#  'PSTNPss_36',
#  'PSTNPss_37',
#  'PSTNPss_38']

# %%
len(feature_idx)
# Out:
# 105

# %%
thr = 0.89
nCV =10
f_score1 = chi2(X_normal1,y_train1)
f_score2 = chi2(X_normal2,y_train2)
f_score3 = chi2(X_normal3,y_train3)
f_score4 = chi2(X_normal4,y_train4)

pValue1 = pd.Series(f_score1[1])
pValue2 = pd.Series(f_score2[1])
pValue3 = pd.Series(f_score3[1])
pValue4 = pd.Series(f_score4[1])
        
list_bad_feature1 = get_bad_features(pValue1,thr)
list_bad_feature2 = get_bad_features(pValue2,thr)
list_bad_feature3 = get_bad_features(pValue3,thr)
list_bad_feature4 = get_bad_features(pValue4,thr)

np.save('list_bad_feature1.npy',list_bad_feature1)
np.save('list_bad_feature2.npy',list_bad_feature2)
np.save('list_bad_feature3.npy',list_bad_feature3)
np.save('list_bad_feature4.npy',list_bad_feature4)

    # reset X_train and X_test , remove the bad feature from dataset 
X_train11 = np.delete(X_train1, list_bad_feature1, axis=1)
X_train21 = np.delete(X_train2, list_bad_feature2, axis=1)
X_train31 = np.delete(X_train3, list_bad_feature3, axis=1)
X_train41 = np.delete(X_train4, list_bad_feature4, axis=1)
    
print(X_train11.shape)
print(X_train21.shape)
print(X_train31.shape)
print(X_train41.shape)

X_test11 = np.delete(X_test1, list_bad_feature1, axis=1)
X_test21 = np.delete(X_test2, list_bad_feature2, axis=1)
X_test31 = np.delete(X_test3, list_bad_feature3, axis=1)
X_test41 = np.delete(X_test4, list_bad_feature4, axis=1)
    
y_train11 = np.array(y_train1)
y_test11 = np.array(y_test1)
y_train21 = np.array(y_train2)
y_test21 = np.array(y_test2)
y_train31 = np.array(y_train3)
y_test31 = np.array(y_test3)
y_train41 = np.array(y_train4)
y_test41 = np.array(y_test4)

tt_data1,tt_targets1,tv_data1,tv_targets1 = CF_Validation(nCV,X_train11,y_train11)
t_vec_train1,t_vec_val1 = get_vec_data(tt_data1,tt_targets1,nCV), get_vec_data(tv_data1,tv_targets1,nCV)
t_vec_test1= [X_test11,y_test11]

tt_data2,tt_targets2,tv_data2,tv_targets2 = CF_Validation(nCV,X_train21,y_train21)
t_vec_train2,t_vec_val2 = get_vec_data(tt_data2,tt_targets2,nCV), get_vec_data(tv_data2,tv_targets2,nCV)
t_vec_test2= [X_test21,y_test21]

tt_data3,tt_targets3,tv_data3,tv_targets3 = CF_Validation(nCV,X_train31,y_train31)
t_vec_train3,t_vec_val3 = get_vec_data(tt_data3,tt_targets3,nCV), get_vec_data(tv_data3,tv_targets3,nCV)
t_vec_test3= [X_test31,y_test31]

tt_data4,tt_targets4,tv_data4,tv_targets4 = CF_Validation(nCV,X_train41,y_train41)
t_vec_train4,t_vec_val4 = get_vec_data(tt_data4,tt_targets4,nCV), get_vec_data(tv_data4,tv_targets4,nCV)
t_vec_test4= [X_test41,y_test41]
# Out:
# (1191, 17)
# (1191, 21)
# (1191, 18)
# (1191, 28)

# %%
pValue3
# Out:
# 0      0.470470
# 1      0.980540
# 2      0.726787
# 3      0.724922
# 4      0.631732
#          ...
# 100    0.886022
# 101    0.900624
# 102    0.709164
# 103    0.822043
# 104    0.688073
# Length: 105, dtype: float64

# %%
len(list_bad_feature3)
len(feature_idx)
# Out:
# 105

# %%
feature_idx
good_feature =[]
for index in range (len(feature_idx)):
    if index not in list_bad_feature3: 
        good_feature.append(feature_idx[index])

# %%
good_feature
len(good_feature)
# Out:
# 18

# %%
total_y_pred_train1,total_y_true_train1,total_y_pred_test1,total_y_true_test1 =Run_ML(nCV,t_vec_train1,t_vec_val1,t_vec_test1,'AB1')
total_y_pred_train2,total_y_true_train2,total_y_pred_test2,total_y_true_test2 =Run_ML(nCV,t_vec_train2,t_vec_val2,t_vec_test2,'AB2')
total_y_pred_train3,total_y_true_train3,total_y_pred_test3,total_y_true_test3 =Run_ML(nCV,t_vec_train3,t_vec_val3,t_vec_test3,'AB3')
total_y_pred_train4,total_y_true_train4,total_y_pred_test4,total_y_true_test4 =Run_ML(nCV,t_vec_train4,t_vec_val4,t_vec_test4,'AB4')

AB_total_performances_train1,AB_total_performances_test1,AB_total_ROC_train1,AB_total_ROC_test1,AB_total_PR_train1,AB_total_PR_test1 = Total_Performances(nCV, total_y_pred_train1,total_y_true_train1,
                                                                         total_y_pred_test1,total_y_true_test1)
AB_total_performances_train2,AB_total_performances_test2,AB_total_ROC_train2,AB_total_ROC_test2,AB_total_PR_train2,AB_total_PR_test2 = Total_Performances(nCV, total_y_pred_train2,total_y_true_train2,
                                                                         total_y_pred_test2,total_y_true_test2)
AB_total_performances_train3,AB_total_performances_test3,AB_total_ROC_train3,AB_total_ROC_test3,AB_total_PR_train3,AB_total_PR_test3 = Total_Performances(nCV, total_y_pred_train3,total_y_true_train3,
                                                                         total_y_pred_test3,total_y_true_test3)
AB_total_performances_train4,AB_total_performances_test4,AB_total_ROC_train4,AB_total_ROC_test4,AB_total_PR_train4,AB_total_PR_test4 = Total_Performances(nCV, total_y_pred_train4,total_y_true_train4,
                                                                         total_y_pred_test4,total_y_true_test4)

# %%
total_y_pred_train1,total_y_true_train1,total_y_pred_test1,total_y_true_test1 =Run_ML(nCV,t_vec_train1,t_vec_val1,t_vec_test1,'GB1')
total_y_pred_train2,total_y_true_train2,total_y_pred_test2,total_y_true_test2 =Run_ML(nCV,t_vec_train2,t_vec_val2,t_vec_test2,'GB2')
total_y_pred_train3,total_y_true_train3,total_y_pred_test3,total_y_true_test3 =Run_ML(nCV,t_vec_train3,t_vec_val3,t_vec_test3,'GB3')
total_y_pred_train4,total_y_true_train4,total_y_pred_test4,total_y_true_test4 =Run_ML(nCV,t_vec_train4,t_vec_val4,t_vec_test4,'GB4')

GB_total_performances_train1,GB_total_performances_test1,GB_total_ROC_train1,GB_total_ROC_test1,GB_total_PR_train1,GB_total_PR_test1 = Total_Performances(nCV, total_y_pred_train1,total_y_true_train1,
                                                                         total_y_pred_test1,total_y_true_test1)
GB_total_performances_train2,GB_total_performances_test2,GB_total_ROC_train2,GB_total_ROC_test2,GB_total_PR_train2,GB_total_PR_test2 = Total_Performances(nCV, total_y_pred_train2,total_y_true_train2,
                                                                         total_y_pred_test2,total_y_true_test2)
GB_total_performances_train3,GB_total_performances_test3,GB_total_ROC_train3,GB_total_ROC_test3,GB_total_PR_train3,GB_total_PR_test3 = Total_Performances(nCV, total_y_pred_train3,total_y_true_train3,
                                                                         total_y_pred_test3,total_y_true_test3)
GB_total_performances_train4,GB_total_performances_test4,GB_total_ROC_train4,GB_total_ROC_test4,GB_total_PR_train4,GB_total_PR_test4 = Total_Performances(nCV, total_y_pred_train4,total_y_true_train4,
                                                                         total_y_pred_test4,total_y_true_test4)

# %%
total_y_pred_train1,total_y_true_train1,total_y_pred_test1,total_y_true_test1 =Run_ML(nCV,t_vec_train1,t_vec_val1,t_vec_test1,'RF1')
total_y_pred_train2,total_y_true_train2,total_y_pred_test2,total_y_true_test2 =Run_ML(nCV,t_vec_train2,t_vec_val2,t_vec_test2,'RF2')
total_y_pred_train3,total_y_true_train3,total_y_pred_test3,total_y_true_test3 =Run_ML(nCV,t_vec_train3,t_vec_val3,t_vec_test3,'RF3')
total_y_pred_train4,total_y_true_train4,total_y_pred_test4,total_y_true_test4 =Run_ML(nCV,t_vec_train4,t_vec_val4,t_vec_test4,'RF4')

RF_total_performances_train1,RF_total_performances_test1,RF_total_ROC_train1,RF_total_ROC_test1,RF_total_PR_train1,RF_total_PR_test1 = Total_Performances(nCV, total_y_pred_train1,total_y_true_train1,
                                                                         total_y_pred_test1,total_y_true_test1)
RF_total_performances_train2,RF_total_performances_test2,RF_total_ROC_train2,RF_total_ROC_test2,RF_total_PR_train2,RF_total_PR_test2 = Total_Performances(nCV, total_y_pred_train2,total_y_true_train2,
                                                                         total_y_pred_test2,total_y_true_test2)
RF_total_performances_train3,RF_total_performances_test3,RF_total_ROC_train3,RF_total_ROC_test3,RF_total_PR_train3,RF_total_PR_test3 = Total_Performances(nCV, total_y_pred_train3,total_y_true_train3,
                                                                         total_y_pred_test3,total_y_true_test3)
RF_total_performances_train4,RF_total_performances_test4,RF_total_ROC_train4,RF_total_ROC_test4,RF_total_PR_train4,RF_total_PR_test4 = Total_Performances(nCV, total_y_pred_train4,total_y_true_train4,
                                                                         total_y_pred_test4,total_y_true_test4)

# %%
total_y_pred_train1,total_y_true_train1,total_y_pred_test1,total_y_true_test1 =Run_ML(nCV,t_vec_train1,t_vec_val1,t_vec_test1,'XGB1')
total_y_pred_train2,total_y_true_train2,total_y_pred_test2,total_y_true_test2 =Run_ML(nCV,t_vec_train2,t_vec_val2,t_vec_test2,'XGB2')
total_y_pred_train3,total_y_true_train3,total_y_pred_test3,total_y_true_test3 =Run_ML(nCV,t_vec_train3,t_vec_val3,t_vec_test3,'XGB3')
total_y_pred_train4,total_y_true_train4,total_y_pred_test4,total_y_true_test4 =Run_ML(nCV,t_vec_train4,t_vec_val4,t_vec_test4,'XGB4')

XGB_total_performances_train1,XGB_total_performances_test1,XGB_total_ROC_train1,XGB_total_ROC_test1,XGB_total_PR_train1,XGB_total_PR_test1 = Total_Performances(nCV, total_y_pred_train1,total_y_true_train1,
                                                                         total_y_pred_test1,total_y_true_test1)
XGB_total_performances_train2,XGB_total_performances_test2,XGB_total_ROC_train2,XGB_total_ROC_test2,XGB_total_PR_train2,XGB_total_PR_test2 = Total_Performances(nCV, total_y_pred_train2,total_y_true_train2,
                                                                         total_y_pred_test2,total_y_true_test2)
XGB_total_performances_train3,XGB_total_performances_test3,XGB_total_ROC_train3,XGB_total_ROC_test3,XGB_total_PR_train3,XGB_total_PR_test3 = Total_Performances(nCV, total_y_pred_train3,total_y_true_train3,
                                                                         total_y_pred_test3,total_y_true_test3)
XGB_total_performances_train4,XGB_total_performances_test4,XGB_total_ROC_train4,XGB_total_ROC_test4,XGB_total_PR_train4,XGB_total_PR_test4 = Total_Performances(nCV, total_y_pred_train4,total_y_true_train4,
                                                                         total_y_pred_test4,total_y_true_test4)

# %%
total_y_pred_train1,total_y_true_train1,total_y_pred_test1,total_y_true_test1 =Run_ML(nCV,t_vec_train1,t_vec_val1,t_vec_test1,'Stacked1')
total_y_pred_train2,total_y_true_train2,total_y_pred_test2,total_y_true_test2 =Run_ML(nCV,t_vec_train2,t_vec_val2,t_vec_test2,'Stacked2')
total_y_pred_train3,total_y_true_train3,total_y_pred_test3,total_y_true_test3 =Run_ML(nCV,t_vec_train3,t_vec_val3,t_vec_test3,'Stacked3')
total_y_pred_train4,total_y_true_train4,total_y_pred_test4,total_y_true_test4 =Run_ML(nCV,t_vec_train4,t_vec_val4,t_vec_test4,'Stacked4')

Stacking_total_performances_train1,Stacking_total_performances_test1,Stacking_total_ROC_train1,Stacking_total_ROC_test1,Stacking_total_PR_train1,Stacking_total_PR_test1 = Total_Performances(nCV, total_y_pred_train1,total_y_true_train1,
                                                                         total_y_pred_test1,total_y_true_test1)
Stacking_total_performances_train2,Stacking_total_performances_test2,Stacking_total_ROC_train2,Stacking_total_ROC_test2,Stacking_total_PR_train2,Stacking_total_PR_test2 = Total_Performances(nCV, total_y_pred_train2,total_y_true_train2,
                                                                         total_y_pred_test2,total_y_true_test2)
Stacking_total_performances_train3,Stacking_total_performances_test3,Stacking_total_ROC_train3,Stacking_total_ROC_test3,Stacking_total_PR_train3,Stacking_total_PR_test3 = Total_Performances(nCV, total_y_pred_train3,total_y_true_train3,
                                                                         total_y_pred_test3,total_y_true_test3)
Stacking_total_performances_train4,Stacking_total_performances_test4,Stacking_total_ROC_train4,Stacking_total_ROC_test4,Stacking_total_PR_train4,Stacking_total_PR_test4 = Total_Performances(nCV, total_y_pred_train4,total_y_true_train4,
                                                                         total_y_pred_test4,total_y_true_test4)

# %%
AB_tot_perf_train = [AB_total_performances_train1, AB_total_performances_train2, 
                     AB_total_performances_train3, AB_total_performances_train4]
AB_tot_perf_test = [AB_total_performances_test1, AB_total_performances_test2, 
                    AB_total_performances_test3, AB_total_performances_test4]
GB_tot_perf_train = [GB_total_performances_train1, GB_total_performances_train2, 
                     GB_total_performances_train3,GB_total_performances_train4]
GB_tot_perf_test = [GB_total_performances_test1, GB_total_performances_test2, 
                    GB_total_performances_test3,GB_total_performances_test4]
RF_tot_perf_train = [RF_total_performances_train1, RF_total_performances_train2,
                     RF_total_performances_train3,RF_total_performances_train4]
RF_tot_perf_test = [RF_total_performances_test1, RF_total_performances_test2, 
                    RF_total_performances_test3,RF_total_performances_test4]
XGB_tot_perf_train = [XGB_total_performances_train1, XGB_total_performances_train2, 
                      XGB_total_performances_train3,XGB_total_performances_train4]
XGB_tot_perf_test = [XGB_total_performances_test1,XGB_total_performances_test2, 
                     XGB_total_performances_test3,XGB_total_performances_test4]
Stacking_tot_perf_train = [Stacking_total_performances_train1, Stacking_total_performances_train2, 
                           Stacking_total_performances_train3,Stacking_total_performances_train4]
Stacking_tot_perf_test = [Stacking_total_performances_test1,Stacking_total_performances_test2, 
                          Stacking_total_performances_test3,Stacking_total_performances_test4]

Create_Tables_RNA_fusion(AB_tot_perf_train,AB_tot_perf_test, 'adaboost')
Create_Tables_RNA_fusion(GB_tot_perf_train,GB_tot_perf_test, 'gradientboost')
Create_Tables_RNA_fusion(RF_tot_perf_train,RF_tot_perf_test, 'random forest')
Create_Tables_RNA_fusion(XGB_tot_perf_train,XGB_tot_perf_test, 'extreme gradient boost')
Create_Tables_RNA_fusion(Stacking_tot_perf_train,Stacking_tot_perf_test, 'Stacking')
# Out:
# +-------------------+--------------+-------+-------+-------+-------+-------+
# | mTrain Model Name |  Data Type   |  ACC  |   SN  |   SP  |  MCC  |  AUC  |
# +-------------------+--------------+-------+-------+-------+-------+-------+
# |      adaboost     | feature_new1 | 0.661 | 0.655 | 0.667 | 0.322 | 0.661 |
# |      adaboost     | feature_new2 | 0.895 | 0.898 | 0.893 | 0.791 | 0.895 |
# |      adaboost     | feature_new3 | 0.914 | 0.915 | 0.913 | 0.828 | 0.914 |
# |      adaboost     | feature_new4 | 0.907 | 0.909 | 0.906 | 0.814 | 0.907 |
# +-------------------+--------------+-------+-------+-------+-------+-------+
# +------------------+--------------+-------+-------+-------+-------+-------+
# | mTest Model Name |  Data Type   |  ACC  |   SN  |   SP  |  MCC  |  AUC  |
# +------------------+--------------+-------+-------+-------+-------+-------+
# |     adaboost     | feature_new1 | 0.504 | 0.478 |  0.53 | 0.008 | 0.504 |
# |     adaboost     | feature_new2 | 0.871 |  0.8  | 0.944 | 0.752 | 0.872 |
# |     adaboost     | feature_new3 |  0.93 | 0.945 | 0.915 | 0.861 |  0.93 |
# |     adaboost     | feature_new4 | 0.847 | 0.826 | 0.867 | 0.695 | 0.846 |
# +------------------+--------------+-------+-------+-------+-------+-------+
# +-------------------+--------------+-------+-------+-------+-------+-------+
# | eTrain Model Name |  Data Type   |  ACC  |   SN  |   SP  |  MCC  |  AUC  |
# +-------------------+--------------+-------+-------+-------+-------+-------+
# |      adaboost     | feature_new1 | 0.009 |  0.03 | 0.018 | 0.017 | 0.009 |
# |      adaboost     | feature_new2 | 0.004 |  0.01 | 0.008 | 0.009 | 0.004 |
# |      adaboost     | feature_new3 | 0.004 | 0.007 | 0.008 | 0.009 | 0.004 |
# |      adaboost     | feature_new4 | 0.007 | 0.007 | 0.011 | 0.014 | 0.007 |
# +-------------------+--------------+-------+-------+-------+-------+-------+
# +------------------+--------------+-------+-------+-------+-------+-------+
# | eTest Model Name |  Data Type   |  ACC  |   SN  |   SP  |  MCC  |  AUC  |
# +------------------+--------------+-------+-------+-------+-------+-------+
# |     adaboost     | feature_new1 | 0.044 | 0.046 | 0.055 | 0.088 | 0.044 |
# |     adaboost     | feature_new2 | 0.012 | 0.029 | 0.018 | 0.021 | 0.012 |
# |     adaboost     | feature_new3 | 0.018 | 0.027 | 0.025 | 0.036 | 0.018 |
# |     adaboost     | feature_new4 | 0.016 | 0.028 | 0.035 | 0.032 | 0.016 |
# +------------------+--------------+-------+-------+-------+-------+-------+
# +-------------------+--------------+-------+-------+-------+-------+-------+
# | mTrain Model Name |  Data Type   |  ACC  |   SN  |   SP  |  MCC  |  AUC  |
# +-------------------+--------------+-------+-------+-------+-------+-------+
# |   gradientboost   | feature_new1 | 0.924 | 0.929 | 0.919 | 0.848 | 0.924 |
# |   gradientboost   | feature_new2 | 0.985 | 0.987 | 0.984 | 0.971 | 0.985 |
# |   gradientboost   | feature_new3 | 0.975 |  0.97 |  0.98 |  0.95 | 0.975 |
# |   gradientboost   | feature_new4 | 0.977 | 0.969 | 0.985 | 0.954 | 0.977 |
# +-------------------+--------------+-------+-------+-------+-------+-------+
# +------------------+--------------+-------+-------+-------+-------+-------+
# | mTest Model Name |  Data Type   |  ACC  |   SN  |   SP  |  MCC  |  AUC  |
# +------------------+--------------+-------+-------+-------+-------+-------+
# |  gradientboost   | feature_new1 | 0.538 | 0.527 | 0.548 | 0.076 | 0.538 |
# |  gradientboost   | feature_new2 | 0.906 | 0.888 | 0.924 | 0.814 | 0.906 |
# |  gradientboost   | feature_new3 | 0.939 |  0.93 | 0.948 | 0.879 | 0.939 |
# |  gradientboost   | feature_new4 | 0.862 | 0.845 | 0.879 | 0.725 | 0.862 |
# +------------------+--------------+-------+-------+-------+-------+-------+
# +-------------------+--------------+-------+-------+-------+-------+-------+
# | eTrain Model Name |  Data Type   |  ACC  |   SN  |   SP  |  MCC  |  AUC  |
# +-------------------+--------------+-------+-------+-------+-------+-------+
# |   gradientboost   | feature_new1 | 0.009 | 0.022 |  0.02 | 0.017 | 0.009 |
# |   gradientboost   | feature_new2 | 0.003 | 0.005 | 0.004 | 0.006 | 0.003 |
# |   gradientboost   | feature_new3 | 0.007 | 0.008 | 0.011 | 0.014 | 0.007 |
# |   gradientboost   | feature_new4 | 0.008 | 0.014 | 0.007 | 0.015 | 0.008 |
# +-------------------+--------------+-------+-------+-------+-------+-------+
# +------------------+--------------+-------+-------+-------+-------+-------+
# | eTest Model Name |  Data Type   |  ACC  |   SN  |   SP  |  MCC  |  AUC  |
# +------------------+--------------+-------+-------+-------+-------+-------+
# |  gradientboost   | feature_new1 |  0.04 | 0.058 | 0.066 | 0.079 |  0.04 |
# |  gradientboost   | feature_new2 | 0.019 | 0.029 | 0.036 | 0.039 | 0.019 |
# |  gradientboost   | feature_new3 | 0.023 | 0.027 | 0.028 | 0.046 | 0.023 |
# |  gradientboost   | feature_new4 | 0.029 | 0.042 | 0.024 | 0.057 | 0.029 |
# +------------------+--------------+-------+-------+-------+-------+-------+
# +-------------------+--------------+-------+-------+-------+-------+-------+
# | mTrain Model Name |  Data Type   |  ACC  |   SN  |   SP  |  MCC  |  AUC  |
# +-------------------+--------------+-------+-------+-------+-------+-------+
# |   random forest   | feature_new1 | 0.936 | 0.938 | 0.935 | 0.872 | 0.936 |
# |   random forest   | feature_new2 | 0.982 | 0.983 | 0.981 | 0.964 | 0.982 |
# |   random forest   | feature_new3 | 0.985 | 0.987 | 0.983 | 0.969 | 0.985 |
# |   random forest   | feature_new4 | 0.983 | 0.984 | 0.983 | 0.966 | 0.983 |
# +-------------------+--------------+-------+-------+-------+-------+-------+
# +------------------+--------------+-------+-------+-------+--------+-------+
# | mTest Model Name |  Data Type   |  ACC  |   SN  |   SP  |  MCC   |  AUC  |
# +------------------+--------------+-------+-------+-------+--------+-------+
# |  random forest   | feature_new1 | 0.495 | 0.482 | 0.509 | -0.008 | 0.496 |
# |  random forest   | feature_new2 | 0.835 | 0.766 | 0.905 | 0.677  | 0.835 |
# |  random forest   | feature_new3 | 0.924 |  0.94 | 0.908 | 0.849  | 0.924 |
# |  random forest   | feature_new4 | 0.833 | 0.838 | 0.828 | 0.667  | 0.833 |
# +------------------+--------------+-------+-------+-------+--------+-------+
# +-------------------+--------------+-------+-------+-------+-------+-------+
# | eTrain Model Name |  Data Type   |  ACC  |   SN  |   SP  |  MCC  |  AUC  |
# +-------------------+--------------+-------+-------+-------+-------+-------+
# |   random forest   | feature_new1 | 0.004 | 0.015 | 0.013 | 0.008 | 0.004 |
# |   random forest   | feature_new2 | 0.004 | 0.006 | 0.006 | 0.008 | 0.004 |
# |   random forest   | feature_new3 | 0.003 | 0.003 | 0.006 | 0.007 | 0.003 |
# |   random forest   | feature_new4 | 0.003 | 0.005 | 0.006 | 0.006 | 0.003 |
# +-------------------+--------------+-------+-------+-------+-------+-------+
# +------------------+--------------+-------+-------+-------+-------+-------+
# | eTest Model Name |  Data Type   |  ACC  |   SN  |   SP  |  MCC  |  AUC  |
# +------------------+--------------+-------+-------+-------+-------+-------+
# |  random forest   | feature_new1 | 0.026 | 0.072 | 0.091 | 0.053 | 0.026 |
# |  random forest   | feature_new2 |  0.02 | 0.029 | 0.021 |  0.04 |  0.02 |
# |  random forest   | feature_new3 | 0.016 | 0.026 | 0.021 | 0.032 | 0.016 |
# |  random forest   | feature_new4 | 0.036 | 0.055 | 0.033 | 0.071 | 0.036 |
# +------------------+--------------+-------+-------+-------+-------+-------+
# +------------------------+--------------+-------+------+-------+-------+-------+
# |   mTrain Model Name    |  Data Type   |  ACC  |  SN  |   SP  |  MCC  |  AUC  |
# +------------------------+--------------+-------+------+-------+-------+-------+
# | extreme gradient boost | feature_new1 | 0.949 | 0.95 | 0.949 | 0.899 | 0.949 |
# | extreme gradient boost | feature_new2 | 0.991 | 0.99 | 0.991 | 0.981 | 0.991 |
# | extreme gradient boost | feature_new3 |  0.99 | 0.99 | 0.989 | 0.979 |  0.99 |
# | extreme gradient boost | feature_new4 |  0.99 | 0.99 |  0.99 |  0.98 |  0.99 |
# +------------------------+--------------+-------+------+-------+-------+-------+
# +------------------------+--------------+-------+-------+-------+--------+-------+
# |    mTest Model Name    |  Data Type   |  ACC  |   SN  |   SP  |  MCC   |  AUC  |
# +------------------------+--------------+-------+-------+-------+--------+-------+
# | extreme gradient boost | feature_new1 | 0.477 | 0.466 | 0.488 | -0.047 | 0.477 |
# | extreme gradient boost | feature_new2 | 0.923 | 0.894 | 0.953 | 0.848  | 0.924 |
# | extreme gradient boost | feature_new3 | 0.977 | 0.982 | 0.973 | 0.955  | 0.977 |
# | extreme gradient boost | feature_new4 | 0.899 | 0.889 | 0.907 | 0.797  | 0.898 |
# +------------------------+--------------+-------+-------+-------+--------+-------+
# +------------------------+--------------+-------+-------+-------+-------+-------+
# |   eTrain Model Name    |  Data Type   |  ACC  |   SN  |   SP  |  MCC  |  AUC  |
# +------------------------+--------------+-------+-------+-------+-------+-------+
# | extreme gradient boost | feature_new1 | 0.002 | 0.008 | 0.007 | 0.005 | 0.002 |
# | extreme gradient boost | feature_new2 | 0.003 | 0.003 | 0.004 | 0.006 | 0.003 |
# | extreme gradient boost | feature_new3 | 0.003 | 0.004 | 0.006 | 0.007 | 0.003 |
# | extreme gradient boost | feature_new4 | 0.002 | 0.005 | 0.006 | 0.005 | 0.002 |
# +------------------------+--------------+-------+-------+-------+-------+-------+
# +------------------------+--------------+-------+-------+-------+-------+-------+
# |    eTest Model Name    |  Data Type   |  ACC  |   SN  |   SP  |  MCC  |  AUC  |
# +------------------------+--------------+-------+-------+-------+-------+-------+
# | extreme gradient boost | feature_new1 | 0.025 | 0.042 | 0.042 | 0.051 | 0.025 |
# | extreme gradient boost | feature_new2 | 0.012 | 0.016 | 0.017 | 0.024 | 0.012 |
# | extreme gradient boost | feature_new3 | 0.009 | 0.014 | 0.014 | 0.019 | 0.009 |
# | extreme gradient boost | feature_new4 | 0.019 | 0.021 | 0.026 | 0.038 | 0.019 |
# +------------------------+--------------+-------+-------+-------+-------+-------+
# +-------------------+--------------+-------+------+-------+--------+-------+
# | mTrain Model Name |  Data Type   |  ACC  |  SN  |   SP  |  MCC   |  AUC  |
# +-------------------+--------------+-------+------+-------+--------+-------+
# |      Stacking     | feature_new1 | 0.334 | 0.29 | 0.379 | -0.338 | 0.334 |
# |      Stacking     | feature_new2 |  0.99 | 0.99 | 0.991 | 0.981  |  0.99 |
# |      Stacking     | feature_new3 |  0.99 | 0.99 | 0.989 | 0.979  |  0.99 |
# |      Stacking     | feature_new4 |  0.99 | 0.99 |  0.99 |  0.98  |  0.99 |
# +-------------------+--------------+-------+------+-------+--------+-------+
# +------------------+--------------+-------+-------+-------+--------+-------+
# | mTest Model Name |  Data Type   |  ACC  |   SN  |   SP  |  MCC   |  AUC  |
# +------------------+--------------+-------+-------+-------+--------+-------+
# |     Stacking     | feature_new1 | 0.499 | 0.446 | 0.553 | -0.003 |  0.5  |
# |     Stacking     | feature_new2 | 0.923 | 0.893 | 0.955 | 0.849  | 0.924 |
# |     Stacking     | feature_new3 | 0.974 | 0.976 | 0.971 | 0.948  | 0.974 |
# |     Stacking     | feature_new4 | 0.898 | 0.883 | 0.912 | 0.796  | 0.898 |
# +------------------+--------------+-------+-------+-------+--------+-------+
# +-------------------+--------------+-------+-------+-------+-------+-------+
# | eTrain Model Name |  Data Type   |  ACC  |   SN  |   SP  |  MCC  |  AUC  |
# +-------------------+--------------+-------+-------+-------+-------+-------+
# |      Stacking     | feature_new1 | 0.402 | 0.403 | 0.426 |  0.81 | 0.402 |
# |      Stacking     | feature_new2 | 0.003 | 0.003 | 0.004 | 0.006 | 0.003 |
# |      Stacking     | feature_new3 | 0.003 | 0.004 | 0.006 | 0.007 | 0.003 |
# |      Stacking     | feature_new4 | 0.003 | 0.003 | 0.006 | 0.005 | 0.003 |
# +-------------------+--------------+-------+-------+-------+-------+-------+
# +------------------+--------------+-------+-------+-------+-------+-------+
# | eTest Model Name |  Data Type   |  ACC  |   SN  |   SP  |  MCC  |  AUC  |
# +------------------+--------------+-------+-------+-------+-------+-------+
# |     Stacking     | feature_new1 | 0.023 | 0.198 | 0.192 | 0.053 | 0.023 |
# |     Stacking     | feature_new2 | 0.013 | 0.017 | 0.018 | 0.025 | 0.013 |
# |     Stacking     | feature_new3 | 0.011 | 0.018 | 0.011 | 0.023 | 0.011 |
# |     Stacking     | feature_new4 | 0.022 |  0.02 | 0.029 | 0.045 | 0.022 |
# +------------------+--------------+-------+-------+-------+-------+-------+

# %%
Plot_Performances_RNA_fusion(AB_tot_perf_train,AB_tot_perf_test, 'adaboost')
Plot_Performances_RNA_fusion(GB_tot_perf_train,GB_tot_perf_test, 'gradientboost')
Plot_Performances_RNA_fusion(RF_tot_perf_train,RF_tot_perf_test, 'random forest')
Plot_Performances_RNA_fusion(XGB_tot_perf_train,XGB_tot_perf_test, 'extreme gradient boost')
Plot_Performances_RNA_fusion(Stacking_tot_perf_train,Stacking_tot_perf_test, 'Stacking')

# %%
def plot_ROC(total_data_roc, method):
    i =0
    for data_roc in total_data_roc:
    # plot ROC 
        fpr,tpr = data_roc[0], data_roc[1]
        plt.plot(fpr,tpr,marker='.',linestyle='--', label=method+'_fold_'+ str(i))
        i = i+1
# axis labels
    plt.plot([0,1],[0,1],marker='.',linestyle='--',color='k')
    plt.title('ROC Curve for ' + str(method))
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
# show the legend
    plt.legend()
# show the plot
    plt.show()

# %%
def plot_PR(total_data_pr, method):
    i =0
    for data_pr in total_data_pr:
    # plot PR 
        prec,rec = data_pr[0], data_pr[1]
        plt.plot(rec,prec,marker='.',linestyle='--', label=method+'_fold_'+ str(i))
        i = i+1
# axis labels
    plt.plot([0,1],[0,1],marker='.',linestyle='--',color='k')
    plt.title('PR Curve for ' + str(method))
    plt.xlabel('Recall')
    plt.ylabel('Precision')
# show the legend
    plt.legend()
# show the plot
    plt.show()

# %%
list_method = ['AB', 'GB','RF','XGB','Stacking']
AB_auc = AB_total_performances_test3[4]
GB_auc = GB_total_performances_test3[4]
RF_auc = RF_total_performances_test3[4]
XGB_auc = XGB_total_performances_test3[4]
Stacking_auc = Stacking_total_performances_test3[4]
total_data_AUC = [AB_auc, GB_auc, RF_auc, XGB_auc,Stacking_auc]
total_data_ROC =[AB_total_ROC_test3,GB_total_ROC_test3,RF_total_ROC_test3,XGB_total_ROC_test3, Stacking_total_ROC_test3]
def plot_ROC_1(list_method, fold):
    i =0
    for method in list_method:
    # plot ROC 
        data_roc=total_data_ROC[i]
        data_auc=total_data_AUC[i]
        fpr,tpr =data_roc[fold] 
        plt.plot(fpr,tpr,marker='.',linestyle='--', label=method+'_fold_'+ str(fold) +" AUC="+str(data_auc[fold]))
        i=i+1
        
# axis labels
    plt.plot([0,1],[0,1],marker='.',linestyle='--',color='k')
    plt.title('ROC Curve fold ' + str(fold))
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
# show the legend
    plt.legend()
# show the plot
    plt.show()

# %%
list_method = ['AB', 'GB','RF','XGB','Stacking']

total_data_PR =[AB_total_PR_test3,GB_total_PR_test3,RF_total_PR_test3,XGB_total_PR_test3,Stacking_total_PR_test3]
def plot_PR_1(list_method, fold):
    i =0
    for method in list_method:
    # plot ROC 
        data_roc=total_data_PR[i]
        
        pre,rec =data_roc[fold] 
        plt.plot(rec,pre,marker='.',linestyle='--', label=method+'_fold_'+ str(fold))
        i=i+1
        
# axis labels
    plt.plot([0,1],[0,1],marker='.',linestyle='--',color='k')
    plt.title('PR Curve fold' + str(fold))
    plt.xlabel('Recall')
    plt.ylabel('Precision')
# show the legend
    plt.legend()
# show the plot
    plt.show()

# %%
for i in range(10):
    plot_ROC_1(list_method, fold=i)

# %%
for i in range(10):
    plot_PR_1(list_method, fold=i)

# %%
plot_ROC(AB_total_ROC_test3, 'AB')
plot_ROC(GB_total_ROC_test3, 'GB')
plot_ROC(RF_total_ROC_test3, 'RF')
plot_ROC(XGB_total_ROC_test3, 'XGB')
plot_ROC(Stacking_total_ROC_test3, 'Stacking')

# %%
plot_PR(AB_total_PR_test3, 'AB')
plot_PR(GB_total_PR_test3, 'GB')
plot_PR(RF_total_PR_test3, 'RF')
plot_PR(XGB_total_PR_test3, 'XGB')
plot_PR(Stacking_total_PR_test3, 'Stacking')

# %%
len(t_vec_test3)
X_xgb= t_vec_test3[0]
y_xgb= t_vec_test3[1]

type(X_xgb)
type(y_xgb)
# Out:
# numpy.ndarray

# %%
len(X_xgb[0])
# Out:
# 18

# %%
# check the most importance feature 
import joblib
loaded_model = joblib.load('XGB_model/XGB3_fold4.joblib')
result = loaded_model.score(X_xgb, y_xgb)

# %%
result
# Out:
# 0.9774436090225563

# %%
good_feature
# Out:
# ['PseKNC_AAC',
#  'PseKNC_AGG',
#  'PseKNC_CCA',
#  'PseKNC_CGA',
#  'PseKNC_CUU',
#  'PseKNC_UGU',
#  'PseKNC_UUA',
#  'PSTNPss_0',
#  'PSTNPss_3',
#  'PSTNPss_4',
#  'PSTNPss_11',
#  'PSTNPss_17',
#  'PSTNPss_19',
#  'PSTNPss_20',
#  'PSTNPss_28',
#  'PSTNPss_30',
#  'PSTNPss_33',
#  'PSTNPss_35']

# %%
sorted_idx = np.argsort(loaded_model.feature_importances_)[::-1]

# %%
plot_importance(loaded_model, max_num_features = 18, title = "Feature Importance (Based on Weight) in XGB Model")
plot_importance(loaded_model, max_num_features = 18, title = "Feature Importance (Based on Cover) in XGB Model",importance_type='cover')
plot_importance(loaded_model, max_num_features = 18, title = "Feature Importance (Based on Gain) XGB Model",importance_type='gain')
plt.show()
